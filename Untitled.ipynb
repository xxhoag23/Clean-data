# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print (os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Customer.csv', 'Untitled.ipynb']

# %%
df = pd.read_excel("Customer.csv
# Out:
#     CustomerID       CustomerName           Address                  Email  \
# 0            1         John Smith   123 Main Street       john@example.com
# 1            2           Jane Doe    456 Elm Street       jane@example.com
# 2            3      David Johnson    789 Oak Avenue      david@example.com
# 3            4     Sarah Williams     321 Pine Road      sarah@example.com
# 4            5      Michael Brown    987 Cedar Lane    michael@example.com
# 5            6        Emily Davis   654 Birch Court      emily@example.com
# 6            7      Robert Wilson   890 Maple Drive     robert@example.com
# 7            8      Olivia Taylor    234 Elm Avenue     olivia@example.com
# 8            9     James Anderson    567 Oak Street      james@example.com
# 9           10      Sophia Thomas     901 Pine Lane     sophia@example.com
# 10          11  Benjamin Martinez    345 Cedar Road   benjamin@example.com
# ...

# %%
missing_value=["N/a","na",np.nan]
df = pd.read_csv("Customer.csv",na_values=missing_value)

# %%
df.isnull().any()
# Out:
# CustomerID      False
# CustomerName    False
# Address         False
# Email           False
# Phone           False
# dtype: bool

# %%
df = df.fillna('')
df
# Out:
#     CustomerID       CustomerName           Address                  Email  \
# 0            1         John Smith   123 Main Street       john@example.com
# 1            2           Jane Doe    456 Elm Street       jane@example.com
# 2            3      David Johnson    789 Oak Avenue      david@example.com
# 3            4     Sarah Williams     321 Pine Road      sarah@example.com
# 4            5      Michael Brown    987 Cedar Lane    michael@example.com
# 5            6        Emily Davis   654 Birch Court      emily@example.com
# 6            7      Robert Wilson   890 Maple Drive     robert@example.com
# 7            8      Olivia Taylor    234 Elm Avenue     olivia@example.com
# 8            9     James Anderson    567 Oak Street      james@example.com
# 9           10      Sophia Thomas     901 Pine Lane     sophia@example.com
# 10          11  Benjamin Martinez    345 Cedar Road   benjamin@example.com
# ...

# %%
sns.heatmap(df.isnull(),yticklabels= False, annot= True)
# Out:
# <Axes: >
